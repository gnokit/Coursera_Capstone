# %% [markdown]
# # Week 3 Assignment of Applied Data Science Capstone

# %% [markdown]
# ## Task 2: Add the latitude and longitude coordinates to the dataframe

# %%
import pandas as pd

# %% [markdown]
# Read the dataframe created in task 1

# %%
df = pd.read_csv('task1.csv')

# %%
df.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Malvern, Rouge
# 1        M1C  Scarborough  Highland Creek, Port Union, Rouge Hill
# 2        M1E  Scarborough     Guildwood]], Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# Install geocoder library

# %%
# !pip install geocoder
import geocoder
# Out:
# Requirement already satisfied: geocoder in /home/jupyterlab/conda/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: ratelim in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (2.18.4)
# Requirement already satisfied: future in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (0.16.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (1.11.0)
# Requirement already satisfied: click in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (6.7)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (2018.8.24)
# distributed 1.21.8 requires msgpack, which is not installed.

# %% [markdown]
# Google provider always run forever. Use Arcgis to get the coordinates

# %%
def get_latlng(postal_code):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
    return lat_lng_coords
    
get_latlng('M4G')
# Out:
# [43.70976500000006, -79.36379132299999]

# %% [markdown]
# Retrieve all Postal Code coordinates

# %%
postal_codes = df['PostalCode']    
coords = [ get_latlng(postal_code) for postal_code in postal_codes.tolist() ]

# %% [markdown]
# Add Latitude and Longitude columns

# %%
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df['Latitude'] = df_coords['Latitude']
df['Longitude'] = df_coords['Longitude']

# %%
df.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.811650
# 1        M1C  Scarborough  Highland Creek, Port Union, Rouge Hill  43.785605
# 2        M1E  Scarborough     Guildwood]], Morningside, West Hill  43.765690
# 3        M1G  Scarborough                                  Woburn  43.768216
# 4        M1H  Scarborough                               Cedarbrae  43.769608
#
#    Longitude
# 0 -79.195561
# 1 -79.158701
# 2 -79.175299
# 3 -79.217610
# 4 -79.239440

# %%
df[df.PostalCode == 'M5G']
# Out:
#    PostalCode           Borough        Neighborhood   Latitude  Longitude
# 57        M5G  Downtown Toronto  Central Bay Street  43.656091  -79.38493

# %% [markdown]
# Save the dataframe for future

# %%
df.to_csv('task2.csv', index=False)

# %%
df
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 72         M6B        North York
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7R       Mississauga
# 86         M7Y      East Toronto
# 87         M8V         Etobicoke
# 88         M8W         Etobicoke
# 89         M8X         Etobicoke
# 90         M8Y         Etobicoke
# 91         M8Z         Etobicoke
# 92         M9A         Etobicoke
# 93         M9B         Etobicoke
# 94         M9C         Etobicoke
# 95         M9L        North York
# 96         M9M        North York
# 97         M9N              York
# 98         M9P         Etobicoke
# 99         M9R         Etobicoke
# 100        M9V         Etobicoke
# 101        M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.811650 -79.195561
# 1               Highland Creek, Port Union, Rouge Hill  43.785605 -79.158701
# 2                  Guildwood]], Morningside, West Hill  43.765690 -79.175299
# 3                                               Woburn  43.768216 -79.217610
# 4                                            Cedarbrae  43.769608 -79.239440
# 5                                  Scarborough Village  43.743085 -79.232172
# 6          East Birchmount Park, Ionview, Kennedy Park  43.726260 -79.263670
# 7                      Clairlea, Golden Mile, Oakridge  43.713213 -79.284910
# 8      Cliffcrest, Cliffside, Scarborough Village West  43.723575 -79.234976
# 9                          Birch Cliff, Cliffside West  43.696690 -79.260069
# 10   Dorset Park, Scarborough Town Centre, Wexford ...  43.759975 -79.268974
# 11                                   Maryvale, Wexford  43.750803 -79.300560
# 12                                           Agincourt  43.793940 -79.267976
# 13             Clarks Corners, Sullivan, Tam O'Shanter  43.784725 -79.299244
# 14   Agincourt North, L'Amoreaux East, Milliken, St...  43.817595 -79.280147
# 15                       L'Amoreaux West, Steeles West  43.800698 -79.320740
# 16                                         Upper Rouge  43.834215 -79.216701
# 17                                   Hillcrest Village  43.802845 -79.356236
# 18                        Fairview, Henry Farm, Oriole  43.780810 -79.347782
# 19                                     Bayview Village  43.781015 -79.380542
# 20                            Silver Hills, York Mills  43.757177 -79.379940
# 21                             Newtonbrook, Willowdale  43.791300 -79.413546
# 22                                    Willowdale South  43.768165 -79.407420
# 23                                     York Mills West  43.747810 -79.400062
# 24                                     Willowdale West  43.777745 -79.445700
# 25                                           Parkwoods  43.752435 -79.329268
# 26                                     Don Mills North  43.749055 -79.362212
# 27                    Don Mills South, Flemingdon Park  43.721375 -79.343415
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.757875 -79.448621
# 29                     Northwood Park, York University  43.764765 -79.488502
# ..                                                 ...        ...        ...
# 72                                           Glencairn  43.707990 -79.448370
# 73                                  Humewood-Cedarvale  43.692105 -79.430355
# 74                               Caledonia-Fairbanks]]  43.688610 -79.451003
# 75                                            Christie  43.668693 -79.420710
# 76                        Dovercourt Village, Dufferin  43.665087 -79.438705
# 77                            Little Portugal, Trinity  43.648525 -79.417757
# 78        Brockton, Exhibition Place, Parkdale Village  43.639410 -79.425436
# 79            Maple Leaf Park, North Park, Upwood Park  43.713810 -79.488301
# 80       Del Ray, Keelsdale, Mount Dennis, Silverthorn  43.694545 -79.484495
# 81                  Runnymede]], ]The Junction North]]  43.675795 -79.481960
# 82                       High Park, The Junction South  43.659730 -79.462812
# 83                              Parkdale, Roncesvalles  43.647870 -79.449762
# 84                                  Runnymede, Swansea  43.649570 -79.475057
# 85               Canada Post Gateway Processing Centre  43.648690 -79.385440
# 86    Business reply mail Processing Centre969 Eastern  43.648690 -79.385440
# 87        Humber Bay Shores, Mimico South, New Toronto  43.609920 -79.498049
# 88                              Alderwood, Long Branch  43.601196 -79.538885
# 89       Montgomery Road, Old Mill North, The Kingsway  43.653590 -79.511130
# 90   Humber Bay, King's Mill Park, Kingsway Park So...  43.632765 -79.489601
# 91   Kingsway Park South West, Mimico NW, Royal Yor...  43.625070 -79.527135
# 92                                    Islington Avenue  43.662302 -79.528305
# 93   Cloverdale, Islington, Martin Grove, Princess ...  43.649738 -79.554055
# 94   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.648573 -79.578250
# 95                                       Humber Summit  43.759500 -79.557028
# 96                                    Emery, Humberlea  43.733665 -79.537477
# 97                                              Weston  43.704905 -79.517712
# 98                                           Westmount  43.696300 -79.530411
# 99   Kingsview Village, Martin Grove Gardens, Richv...  43.686810 -79.557284
# 100  Albion Gardens, Beaumond Heights, Humbergate, ...  43.743795 -79.585431
# 101                                          Northwest  43.711740 -79.579410
#
# [102 rows x 5 columns]
